# %%
import pandas as pd

df = pd.read_pickle("/workspaces/fm/fm/notebooks/webpage/df-full.pkl")
df[df["dataset"] == "qm9"]
# Out:
#       dataset                                          structure       2d_x  \
# 16152     qm9  [[-0.1274721  2.3425972 -0.2367877] C, [-0.093... -20.842764
# 16153     qm9  [[-0.2049721  2.3102973 -0.2620877] O, [-0.078... -11.724689
# 16154     qm9  [[-0.52317214  2.2171972  -0.16668771] C, [-0.... -20.934710
# 16155     qm9  [[-0.2130721   2.389897   -0.16178772] C, [-0.... -33.713631
# 16156     qm9  [[-0.11247211  2.2431972  -0.34658772] C, [-0.... -15.509194
# ...       ...                                                ...        ...
# 17195     qm9  [[ 0.32635328  2.426664   -0.3835085 ] N, [ 0.... -13.987875
# 17196     qm9  [[ 0.8215533  1.4424641 -1.2887084] O, [ 0.110... -21.574337
# 17197     qm9  [[ 0.6541533   2.4254642  -0.32940853] O, [ 0....  -6.451044
# 17198     qm9  [[ 0.44675326  2.7138643  -0.48100853] C, [ 0.... -13.988735
# 17199     qm9  [[ 0.12225328  2.482964   -0.56510854] O, [ 0....  -9.657672
#
#             2d_y       3d_x       3d_y       3d_z dataset_name subset  \
# 16152 -69.160103  -8.594269 -13.698781   9.484163          QM9
# 16153 -81.135910  -7.330738 -18.164793   2.028309          QM9
# 16154 -77.498993 -12.685884 -17.329952   6.506678          QM9
# 16155 -84.108429 -10.444674 -23.764544  12.019032          QM9
# 16156 -74.977722 -10.983833 -14.495315   4.842113          QM9
# ...          ...        ...        ...        ...          ...    ...
# 17195 -65.471451  -8.634264 -10.806345   7.806369          QM9
# 17196 -81.044464  -9.150553 -19.295874   6.432492          QM9
# 17197 -64.150856  -4.257300 -10.366927   7.226886          QM9
# 17198 -74.059341  -9.160545 -14.334983   4.410115          QM9
# 17199 -82.491348  -8.467598 -16.900452   0.124561          QM9
#
#              stage dataset_full_name                              description  \
# 16152  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# 16153  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# 16154  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# 16155  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# 16156  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# ...            ...               ...                                      ...
# 17195  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# 17196  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# 17197  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# 17198  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
# 17199  Fine-tuning               QM9  QM9 Quantum Chemical Properties Dataset
#
#                                                url
# 16152  https://www.nature.com/articles/sdata201422
# 16153  https://www.nature.com/articles/sdata201422
# 16154  https://www.nature.com/articles/sdata201422
# 16155  https://www.nature.com/articles/sdata201422
# 16156  https://www.nature.com/articles/sdata201422
# ...                                            ...
# 17195  https://www.nature.com/articles/sdata201422
# 17196  https://www.nature.com/articles/sdata201422
# 17197  https://www.nature.com/articles/sdata201422
# 17198  https://www.nature.com/articles/sdata201422
# 17199  https://www.nature.com/articles/sdata201422
#
# [1048 rows x 13 columns]

# %%
# Keep the original indices for later user
df["original_index"] = df.index.values
df
# Out:
#                   dataset                                          structure  \
# 0      matbench.mp_e_form  [[ 0.78697842 -1.5152179   3.46403885] Li, [ 1...
# 1      matbench.mp_e_form  [[0.63675576 3.86094308 9.92762947] V, [0.6529...
# 2      matbench.mp_e_form  [[ 0.         0.        -3.9570837] Rb, [ 0.  ...
# 3      matbench.mp_e_form  [[ 3.00214791 -0.93396616  1.98921537] Li, [2....
# 4      matbench.mp_e_form  [[2.76518726 0.95865363 1.37575877] Ni, [0.532...
# ...                   ...                                                ...
# 17195                 qm9  [[ 0.32635328  2.426664   -0.3835085 ] N, [ 0....
# 17196                 qm9  [[ 0.8215533  1.4424641 -1.2887084] O, [ 0.110...
# 17197                 qm9  [[ 0.6541533   2.4254642  -0.32940853] O, [ 0....
# 17198                 qm9  [[ 0.44675326  2.7138643  -0.48100853] C, [ 0....
# 17199                 qm9  [[ 0.12225328  2.482964   -0.56510854] O, [ 0....
#
#             2d_x       2d_y       3d_x       3d_y       3d_z dataset_name  \
# 0     -24.277473  37.250996 -19.434237   2.920142 -12.789039     MatBench
# 1     -34.659958   1.423893  -8.118999  -2.583727  -3.859672     MatBench
# 2     -53.466888  29.784603 -12.964548   9.229770  -0.297288     MatBench
# 3     -50.305542  26.561850 -13.121795   6.174547  -1.123981     MatBench
# 4     -32.217903  67.414482 -10.313452  14.108568 -11.285166     MatBench
# ...          ...        ...        ...        ...        ...          ...
# 17195 -13.987875 -65.471451  -8.634264 -10.806345   7.806369          QM9
# 17196 -21.574337 -81.044464  -9.150553 -19.295874   6.432492          QM9
# 17197  -6.451044 -64.150856  -4.257300 -10.366927   7.226886          QM9
# 17198 -13.988735 -74.059341  -9.160545 -14.334983   4.410115          QM9
# 17199  -9.657672 -82.491348  -8.467598 -16.900452   0.124561          QM9
#
#        subset        stage  dataset_full_name  \
# 0      e_form  Fine-tuning  MatBench - e_form
# 1      e_form  Fine-tuning  MatBench - e_form
# 2      e_form  Fine-tuning  MatBench - e_form
# 3      e_form  Fine-tuning  MatBench - e_form
# 4      e_form  Fine-tuning  MatBench - e_form
# ...       ...          ...                ...
# 17195          Fine-tuning                QM9
# 17196          Fine-tuning                QM9
# 17197          Fine-tuning                QM9
# 17198          Fine-tuning                QM9
# 17199          Fine-tuning                QM9
#
#                                    description  \
# 0                  MatBench Benchmarking Suite
# 1                  MatBench Benchmarking Suite
# 2                  MatBench Benchmarking Suite
# 3                  MatBench Benchmarking Suite
# 4                  MatBench Benchmarking Suite
# ...                                        ...
# 17195  QM9 Quantum Chemical Properties Dataset
# 17196  QM9 Quantum Chemical Properties Dataset
# 17197  QM9 Quantum Chemical Properties Dataset
# 17198  QM9 Quantum Chemical Properties Dataset
# 17199  QM9 Quantum Chemical Properties Dataset
#
#                                                url  original_index
# 0           https://matbench.materialsproject.org/               0
# 1           https://matbench.materialsproject.org/               1
# 2           https://matbench.materialsproject.org/               2
# 3           https://matbench.materialsproject.org/               3
# 4           https://matbench.materialsproject.org/               4
# ...                                            ...             ...
# 17195  https://www.nature.com/articles/sdata201422           17195
# 17196  https://www.nature.com/articles/sdata201422           17196
# 17197  https://www.nature.com/articles/sdata201422           17197
# 17198  https://www.nature.com/articles/sdata201422           17198
# 17199  https://www.nature.com/articles/sdata201422           17199
#
# [17200 rows x 14 columns]

# %%
# # Update the df to reduce the number of data points for each unique "dataset"
# # to be 1/16 of the original number of data points.
df["datasetkey"] = df["dataset"].astype("category").cat.codes
df_new = (
    df.groupby("datasetkey")
    .apply(lambda x: x.sample(frac=1 / 6), include_groups=False)
    .reset_index(drop=True)
)
df_new

# import numpy as np

# # We already have the sampled indices -- just use those
# idxs = np.load("./small_idxs.npy")
# df_new = df.loc[idxs].reset_index(drop=True)
# df_new
# Out:
#                          dataset  \
# 0            matbench.dielectric
# 1            matbench.dielectric
# 2            matbench.dielectric
# 3            matbench.dielectric
# 4            matbench.dielectric
# ...                          ...
# 2870  spice.solvated_amino_acids
# 2871  spice.solvated_amino_acids
# 2872  spice.solvated_amino_acids
# 2873  spice.solvated_amino_acids
# 2874  spice.solvated_amino_acids
#
#                                               structure       2d_x       2d_y  \
# 0     [[5.00229645 2.99566603 2.76575899] Li, [2.381... -20.924961  43.538120
# 1     [[1.05560446 3.16681361 0.        ] F, [3.1668... -18.792795  56.655403
# 2     [[ 2.87831187  3.22713351 22.16319656] Br, [ 0... -33.478405  68.698433
# 3     [[1.86745191 0.45245212 5.61367846] F, [1.7137... -17.108170  51.624454
# 4     [[ 0.17882626  5.12199402 -0.12719865] V, [3.9... -16.406113  50.252506
# ...                                                 ...        ...        ...
# 2870  [[23.12498  18.906118 14.452415] O, [14.759885...  11.704685  20.358120
# 2871  [[15.06595  18.805973 24.70878 ] O, [15.448091...   1.054338  19.113787
# 2872  [[21.79798  25.479414 24.247139] O, [20.09852 ...  -0.611938  18.240498
# 2873  [[26.765219 18.019241 20.43421 ] O, [19.897085...   3.423499  18.673550
# 2874  [[17.463802 12.731884 18.699774] O, [23.981487...   0.751585  17.580589
#
#            3d_x       3d_y       3d_z dataset_name                subset  \
# 0    -19.051847   7.754231 -13.493033     MatBench            dielectric
# 1    -17.533155  12.427681 -14.448886     MatBench            dielectric
# 2    -10.083833  15.907990 -11.362943     MatBench            dielectric
# 3    -18.234531  10.837628 -17.907209     MatBench            dielectric
# 4    -17.557388  10.018288 -18.563683     MatBench            dielectric
# ...         ...        ...        ...          ...                   ...
# 2870  13.655184  -4.350087 -20.524630        SPICE  solvated_amino_acids
# 2871  14.287766  -3.489104 -14.071879        SPICE  solvated_amino_acids
# 2872  15.003216  -3.486176 -13.131898        SPICE  solvated_amino_acids
# 2873  16.690420  -3.218456 -15.911716        SPICE  solvated_amino_acids
# 2874  15.749787  -4.127564 -13.879321        SPICE  solvated_amino_acids
#
#             stage             dataset_full_name                  description  \
# 0     Fine-tuning         MatBench - dielectric  MatBench Benchmarking Suite
# 1     Fine-tuning         MatBench - dielectric  MatBench Benchmarking Suite
# 2     Fine-tuning         MatBench - dielectric  MatBench Benchmarking Suite
# 3     Fine-tuning         MatBench - dielectric  MatBench Benchmarking Suite
# 4     Fine-tuning         MatBench - dielectric  MatBench Benchmarking Suite
# ...           ...                           ...                          ...
# 2870  Fine-tuning  SPICE - solvated_amino_acids                SPICE Dataset
# 2871  Fine-tuning  SPICE - solvated_amino_acids                SPICE Dataset
# 2872  Fine-tuning  SPICE - solvated_amino_acids                SPICE Dataset
# 2873  Fine-tuning  SPICE - solvated_amino_acids                SPICE Dataset
# 2874  Fine-tuning  SPICE - solvated_amino_acids                SPICE Dataset
#
#                                           url  original_index
# 0      https://matbench.materialsproject.org/            1029
# 1      https://matbench.materialsproject.org/            1043
# 2      https://matbench.materialsproject.org/            1107
# 3      https://matbench.materialsproject.org/            1036
# 4      https://matbench.materialsproject.org/            1174
# ...                                       ...             ...
# 2870  https://github.com/openmm/spice-dataset           15914
# 2871  https://github.com/openmm/spice-dataset           16115
# 2872  https://github.com/openmm/spice-dataset           15948
# 2873  https://github.com/openmm/spice-dataset           16064
# 2874  https://github.com/openmm/spice-dataset           15904
#
# [2875 rows x 14 columns]

# %%
from pymatgen.core.structure import Molecule


def update(structure: Molecule):
    if not isinstance(structure, Molecule):
        return structure

    # Update positions to center around the origin
    coords = structure.cart_coords
    coords -= coords.mean(axis=0)
    structure = Molecule(structure.species, coords)

    return structure


df_new["structure"] = df_new["structure"].apply(update)

# %%
# # Update OC20 and OC22 to set PBC to (x, y) but not z
# from pymatgen.core import Lattice, Structure


# def update(structure: Structure):
#     if not isinstance(structure, Structure):
#         return structure

#     structure = structure.copy()
#     structure.lattice = Lattice(structure.lattice.matrix, pbc=(True, True, False))

#     return structure


# oc20_or_oc22 = df_new["dataset_name"].isin(["OC20", "OC22"])
# # df_new["structure"][oc20_or_oc22] = df_new["structure"][oc20_or_oc22].apply(update)
# df_new.loc[oc20_or_oc22, "structure"] = df_new.loc[oc20_or_oc22, "structure"].apply(
#     update
# )

# %%
df_new.to_pickle("../df_small.pkl")

# %%
structure = df_new[df_new["subset"] == "benzene"].iloc[0].structure
structure
# Out:
# Molecule Summary
# Site: C (-1.0982, -0.6571, -0.5638)
# Site: C (0.1808, -0.7764, -1.1306)
# Site: C (1.2632, -0.0284, -0.6502)
# Site: C (1.0796, 0.7236, 0.5799)
# Site: C (-0.1525, 0.7411, 1.1667)
# Site: C (-1.2352, 0.0877, 0.5876)
# Site: H (-1.8850, -1.2153, -1.1046)
# Site: H (0.2420, -1.5113, -1.9429)
# Site: H (2.2429, 0.0231, -1.1837)
# Site: H (1.9527, 1.1766, 1.0508)
# Site: H (-0.3643, 1.2342, 2.1152)
# Site: H (-2.2261, 0.2017, 1.0760)
