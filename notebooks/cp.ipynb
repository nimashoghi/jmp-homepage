# %%
import pandas as pd

df = pd.read_pickle("/workspaces/jmp-homepage/df_small.pkl")
commands = []
for idx in df.original_index:
    commands.append(
        f"cp /mnt/datasets/jmprenders/flat/{idx}.jpeg ./static/images/renders/{idx}.jpeg"
    )
print("\n".join(commands))
# Out:
# cp /mnt/datasets/jmprenders/flat/1111.jpeg ./static/images/renders/1111.jpeg
# cp /mnt/datasets/jmprenders/flat/1162.jpeg ./static/images/renders/1162.jpeg
# cp /mnt/datasets/jmprenders/flat/1277.jpeg ./static/images/renders/1277.jpeg
# cp /mnt/datasets/jmprenders/flat/1279.jpeg ./static/images/renders/1279.jpeg
# cp /mnt/datasets/jmprenders/flat/1251.jpeg ./static/images/renders/1251.jpeg
# cp /mnt/datasets/jmprenders/flat/1107.jpeg ./static/images/renders/1107.jpeg
# cp /mnt/datasets/jmprenders/flat/1030.jpeg ./static/images/renders/1030.jpeg
# cp /mnt/datasets/jmprenders/flat/1149.jpeg ./static/images/renders/1149.jpeg
# cp /mnt/datasets/jmprenders/flat/1224.jpeg ./static/images/renders/1224.jpeg
# cp /mnt/datasets/jmprenders/flat/1138.jpeg ./static/images/renders/1138.jpeg
# cp /mnt/datasets/jmprenders/flat/1121.jpeg ./static/images/renders/1121.jpeg
# cp /mnt/datasets/jmprenders/flat/1156.jpeg ./static/images/renders/1156.jpeg
# ...
