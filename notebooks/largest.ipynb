# %%
import pandas as pd

df = pd.read_pickle("/workspaces/jmp-homepage/df_small.pkl")
df
# Out:
#                          dataset  \
# 0            matbench.dielectric
# 1            matbench.dielectric
# 2            matbench.dielectric
# 3            matbench.dielectric
# 4            matbench.dielectric
# ...                          ...
# 2870  spice.solvated_amino_acids
# 2871  spice.solvated_amino_acids
# 2872  spice.solvated_amino_acids
# 2873  spice.solvated_amino_acids
# 2874  spice.solvated_amino_acids
#
#                                               structure       2d_x       2d_y  \
# 0     [[4.09931755 3.98269629 6.67670059] Sr, [4.099... -50.486404  67.012833
# 1     [[0.0634895  5.18064928 5.5836854 ] Pb, [2.689... -66.651222   4.237054
# 2     [[4.58825731 5.38632202 1.72110856] Ho, [-2.37... -23.733160  62.251606
# 3     [[ 5.54153538  4.48080969 10.32118225] K, [5.5... -44.986675  37.928719
# 4     [[0.        0.        4.0844059] B, [0.       ... -55.880871  55.663666
# ...                                                 ...        ...        ...
# ...

# %%
len7(df.iloc[0].structure)
# Out:
# 21

# %%
df["natoms"] = df["structure"].apply(lambda x: len(x))
df
# Out:
#                          dataset  \
# 0            matbench.dielectric
# 1            matbench.dielectric
# 2            matbench.dielectric
# 3            matbench.dielectric
# 4            matbench.dielectric
# ...                          ...
# 2870  spice.solvated_amino_acids
# 2871  spice.solvated_amino_acids
# 2872  spice.solvated_amino_acids
# 2873  spice.solvated_amino_acids
# 2874  spice.solvated_amino_acids
#
#                                               structure       2d_x       2d_y  \
# 0     [[4.09931755 3.98269629 6.67670059] Sr, [4.099... -50.486404  67.012833
# 1     [[0.0634895  5.18064928 5.5836854 ] Pb, [2.689... -66.651222   4.237054
# 2     [[4.58825731 5.38632202 1.72110856] Ho, [-2.37... -23.733160  62.251606
# 3     [[ 5.54153538  4.48080969 10.32118225] K, [5.5... -44.986675  37.928719
# 4     [[0.        0.        4.0844059] B, [0.       ... -55.880871  55.663666
# ...                                                 ...        ...        ...
# ...

# %%
# Get the idx of the structure with the most atoms
idx = df["natoms"].idxmax()
print(idx, df.iloc[idx])
# Out:
# 2680 dataset                                                           qmof
# structure            [[ 7.25665998 14.34751987  2.54094005] Zn, [8....
# 2d_x                                                         -7.746197
# 2d_y                                                          5.747162
# 3d_x                                                         -1.717885
# 3d_y                                                          7.430882
# 3d_z                                                          5.765888
# dataset_name                                                      QMOF
# subset
# stage                                                      Fine-tuning
# dataset_full_name                                                 QMOF
# description                                   The Quantum MOF Database
# url                             https://github.com/Andrew-S-Rosen/QMOF
# original_index                                                    2629
# ...
